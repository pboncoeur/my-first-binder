# %%
! pip install appmode
! jupyter nbextension     enable --py --sys-prefix appmode
! jupyter serverextension enable --py --sys-prefix appmode
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: appmode in /home/mymate/.local/lib/python3.10/site-packages (0.9.0)
# Requirement already satisfied: notebook>=5 in /home/mymate/.local/lib/python3.10/site-packages (from appmode) (7.1.1)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/mymate/.local/lib/python3.10/site-packages (from notebook>=5->appmode) (0.2.4)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /home/mymate/.local/lib/python3.10/site-packages (from notebook>=5->appmode) (2.25.3)
# Requirement already satisfied: tornado>=6.2.0 in /home/mymate/.local/lib/python3.10/site-packages (from notebook>=5->appmode) (6.4)
# Requirement already satisfied: jupyterlab<4.2,>=4.1.1 in /home/mymate/.local/lib/python3.10/site-packages (from notebook>=5->appmode) (4.1.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/mymate/.local/lib/python3.10/site-packages (from notebook>=5->appmode) (2.13.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/mymate/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5->appmode) (8.6.0)
# Requirement already satisfied: websocket-client in /home/mymate/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5->appmode) (1.7.0)
# Requirement already satisfied: jinja2 in /home/mymate/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5->appmode) (3.1.3)
# Requirement already satisfied: pyzmq>=24 in /home/mymate/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5->appmode) (25.1.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/mymate/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5->appmode) (5.7.1)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/mymate/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5->appmode) (7.16.2)
# Requirement already satisfied: jupyter-server-terminals in /home/mymate/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5->appmode) (0.5.2)
# Requirement already satisfied: overrides in /home/mymate/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5->appmode) (7.7.0)
# Requirement already satisfied: nbformat>=5.3.0 in /home/mymate/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5->appmode) (5.9.2)
# Requirement already satisfied: argon2-cffi in /home/mymate/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5->appmode) (23.1.0)
# Requirement already satisfied: anyio>=3.1.0 in /home/mymate/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5->appmode) (4.3.0)
# Requirement already satisfied: prometheus-client in /home/mymate/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5->appmode) (0.20.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/mymate/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5->appmode) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/mymate/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5->appmode) (0.18.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /home/mymate/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5->appmode) (0.9.0)
# Requirement already satisfied: traitlets>=5.6.0 in /home/mymate/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5->appmode) (5.14.1)
# Requirement already satisfied: packaging in /home/mymate/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=5->appmode) (23.2)
# Requirement already satisfied: tomli in /home/mymate/.local/lib/python3.10/site-packages (from jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (2.0.1)
# Requirement already satisfied: httpx>=0.25.0 in /home/mymate/.local/lib/python3.10/site-packages (from jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (0.27.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/mymate/.local/lib/python3.10/site-packages (from jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (2.0.4)
# Requirement already satisfied: ipykernel in /home/mymate/.local/lib/python3.10/site-packages (from jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (6.29.3)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/mymate/.local/lib/python3.10/site-packages (from jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (2.2.3)
# Requirement already satisfied: babel>=2.10 in /home/mymate/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=5->appmode) (2.14.0)
# Requirement already satisfied: requests>=2.31 in /home/mymate/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=5->appmode) (2.31.0)
# Requirement already satisfied: json5>=0.9.0 in /home/mymate/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=5->appmode) (0.9.20)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/mymate/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=5->appmode) (4.21.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/mymate/.local/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (1.2.0)
# Requirement already satisfied: idna>=2.8 in /usr/lib/python3/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (3.3)
# Requirement already satisfied: typing-extensions>=4.1 in /home/mymate/.local/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (4.10.0)
# Requirement already satisfied: sniffio>=1.1 in /home/mymate/.local/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (1.3.1)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (2020.6.20)
# Requirement already satisfied: httpcore==1.* in /home/mymate/.local/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/mymate/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (2.0.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/mymate/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=5->appmode) (0.18.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/mymate/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=5->appmode) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/mymate/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=5->appmode) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/mymate/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=5->appmode) (0.33.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mymate/.local/lib/python3.10/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /home/mymate/.local/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (4.2.0)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/mymate/.local/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (0.1.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/mymate/.local/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /home/mymate/.local/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (5.3.1)
# Requirement already satisfied: rfc3339-validator in /home/mymate/.local/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (0.1.4)
# Requirement already satisfied: beautifulsoup4 in /home/mymate/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (4.12.3)
# Requirement already satisfied: defusedxml in /home/mymate/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (0.7.1)
# Requirement already satisfied: pygments>=2.4.1 in /home/mymate/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (2.17.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/mymate/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (1.5.1)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/mymate/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (3.0.2)
# Requirement already satisfied: bleach!=5.0.0 in /home/mymate/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (6.1.0)
# Requirement already satisfied: tinycss2 in /home/mymate/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (1.2.1)
# Requirement already satisfied: jupyterlab-pygments in /home/mymate/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (0.3.0)
# Requirement already satisfied: nbclient>=0.5.0 in /home/mymate/.local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (0.9.0)
# Requirement already satisfied: fastjsonschema in /home/mymate/.local/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (2.19.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=5->appmode) (1.26.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mymate/.local/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=5->appmode) (3.3.2)
# Requirement already satisfied: ptyprocess in /usr/lib/python3/dist-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/mymate/.local/lib/python3.10/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (21.2.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/mymate/.local/lib/python3.10/site-packages (from ipykernel->jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (0.1.6)
# Requirement already satisfied: ipython>=7.23.1 in /home/mymate/.local/lib/python3.10/site-packages (from ipykernel->jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (8.22.2)
# Requirement already satisfied: psutil in /usr/lib/python3/dist-packages (from ipykernel->jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (5.9.0)
# Requirement already satisfied: debugpy>=1.6.5 in /home/mymate/.local/lib/python3.10/site-packages (from ipykernel->jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (1.8.1)
# Requirement already satisfied: nest-asyncio in /home/mymate/.local/lib/python3.10/site-packages (from ipykernel->jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (1.6.0)
# Requirement already satisfied: comm>=0.1.1 in /home/mymate/.local/lib/python3.10/site-packages (from ipykernel->jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (0.2.1)
# Requirement already satisfied: webencodings in /home/mymate/.local/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3/dist-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (1.16.0)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (4.8.0)
# Requirement already satisfied: stack-data in /home/mymate/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (0.6.3)
# Requirement already satisfied: decorator in /home/mymate/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/mymate/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/mymate/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (3.0.43)
# Requirement already satisfied: jsonpointer>1.13 in /home/mymate/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=5->appmode) (2.4)
# Requirement already satisfied: uri-template in /home/mymate/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=5->appmode) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /home/mymate/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=5->appmode) (1.13)
# Requirement already satisfied: isoduration in /home/mymate/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=5->appmode) (20.11.0)
# Requirement already satisfied: fqdn in /home/mymate/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=5->appmode) (1.5.1)
# Requirement already satisfied: cffi>=1.0.1 in /home/mymate/.local/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /home/mymate/.local/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (2.5)
# Requirement already satisfied: pycparser in /home/mymate/.local/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=5->appmode) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/mymate/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (0.8.3)
# Requirement already satisfied: wcwidth in /home/mymate/.local/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (0.2.13)
# Requirement already satisfied: arrow>=0.15.0 in /home/mymate/.local/lib/python3.10/site-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=5->appmode) (1.3.0)
# Requirement already satisfied: pure-eval in /home/mymate/.local/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /home/mymate/.local/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/mymate/.local/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<4.2,>=4.1.1->notebook>=5->appmode) (2.4.1)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/mymate/.local/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=5->appmode) (2.8.19.20240106)
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: dejavu events execute kernel kernelspec lab
# labextension labhub migrate nbconvert notebook run server troubleshoot trust
#
# Jupyter command `jupyter-nbextension` not found.
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: dejavu events execute kernel kernelspec lab
# labextension labhub migrate nbconvert notebook run server troubleshoot trust
#
# Jupyter command `jupyter-serverextension` not found.

# %%
! pip install ipywidgets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.2-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 KB 602.2 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Requirement already satisfied: ipython>=6.1.0 in /home/mymate/.local/lib/python3.10/site-packages (from ipywidgets) (8.22.2)
# Requirement already satisfied: comm>=0.1.3 in /home/mymate/.local/lib/python3.10/site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: traitlets>=4.3.1 in /home/mymate/.local/lib/python3.10/site-packages (from ipywidgets) (5.14.1)
# Collecting widgetsnbextension~=4.0.10
#   Downloading widgetsnbextension-4.0.10-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 5.1 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting jupyterlab-widgets~=3.0.10
#   Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl (215 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.0/215.0 KB 3.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: stack-data in /home/mymate/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: jedi>=0.16 in /home/mymate/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: decorator in /home/mymate/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /home/mymate/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: exceptiongroup in /home/mymate/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/mymate/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/mymate/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/mymate/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: wcwidth in /home/mymate/.local/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/mymate/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: pure-eval in /home/mymate/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /home/mymate/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets
# Successfully installed ipywidgets-8.1.2 jupyterlab-widgets-3.0.10 widgetsnbextension-4.0.10

# %%
from __future__ import division
import ipywidgets as ipw

output = ipw.Text(placeholder="0", layout=ipw.Layout(width="190px"),  disabled=True)

def on_click(btn):
    if btn.description == "=":
        try:
            output.value = str(eval(output.value))
        except:
            output.value = "ERROR"
    elif btn.description == "AC":
        output.value = ""
    elif btn.description == "del":
        output.value = output.value[:-1]
    else:
        output.value = output.value + btn.description

def mk_btn(description):
    btn = ipw.Button(description=description, layout=ipw.Layout(width="45px"))
    btn.on_click(on_click)
    return btn

row0 = ipw.HBox([mk_btn(d) for d in ("(", ")", "del", "AC")])
row1 = ipw.HBox([mk_btn(d) for d in ("7", "8", "9", " / ")])
row2 = ipw.HBox([mk_btn(d) for d in ("4", "5", "6", " * ")])
row3 = ipw.HBox([mk_btn(d) for d in ("1", "2", "3", " - ")])
row4 = ipw.HBox([mk_btn(d) for d in ("0", ".", "=", " + ")])
ipw.VBox((output, row0, row1, row2, row3, row4))
# Out:
# VBox(children=(Text(value='', disabled=True, layout=Layout(width='190px'), placeholder='0'), HBox(children=(Bu…
